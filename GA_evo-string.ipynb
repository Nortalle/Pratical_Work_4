# %%
from pyevolve import G1DList
from pyevolve import GSimpleGA
from pyevolve import Selectors
from pyevolve import Statistics

# %%
def fitness(chromosome):
    score = 0.0
    target = 'METHINKS_IT_IS_LIKE_A_WEASEL'
    # iterate over the chromosome
    for i in range(0,len(chromosome)):
        if chr(chromosome[i]) == target[i]:
            score += 1
    return score

# %%
def current_best(ga_engine):
    # Here you have access to the GA Engine
    best = ga.bestIndividual()
    for i in range(0,len(best)):
        print(chr(best[i]))
    return False

# %%
# Chromosome representation

# genome = List of elements
genome = G1DList.G1DList(28)

# elements = values in the range rangemin and rangemax
# ASCII(65) = 'A' .... ASCII(95) = '_'
genome.setParams(rangemin=65, rangemax=95)

# how to compute the fitness
genome.evaluator.set(fitness)

# GA initialisation
ga = GSimpleGA.GSimpleGA(genome)
ga.setPopulationSize(200)
ga.setMutationRate(0.05)
ga.setCrossoverRate(0.9)
ga.selector.set(Selectors.GTournamentSelector)
ga.setElitism(True)

# Number of generations
ga.setGenerations(500)

# In case we want to monitor the evolution process
# execute the function current_best every generation
#ga.stepCallback.set(current_best)

ga.evolve(freq_stats=10)

# Final best solution
best = ga.bestIndividual()

for i in range(0,len(best)):
    print(chr(best[i]))
# Out:
# Gen. 0 (0.00%): Max/Min/Avg Fitness(Raw) [1.10(5.00)/0.87(0.00)/0.91(0.92)]
# Gen. 10 (2.00%): Max/Min/Avg Fitness(Raw) [6.86(9.00)/4.07(1.00)/5.72(5.72)]
# Gen. 20 (4.00%): Max/Min/Avg Fitness(Raw) [12.02(14.00)/8.00(6.00)/10.02(10.02)]
# Gen. 30 (6.00%): Max/Min/Avg Fitness(Raw) [15.69(18.00)/10.91(9.00)/13.07(13.07)]
# Gen. 40 (8.00%): Max/Min/Avg Fitness(Raw) [18.13(20.00)/12.57(11.00)/15.10(15.11)]
# Gen. 50 (10.00%): Max/Min/Avg Fitness(Raw) [20.35(22.00)/14.29(13.00)/16.96(16.96)]
# Gen. 60 (12.00%): Max/Min/Avg Fitness(Raw) [21.85(25.00)/15.95(14.00)/18.21(18.21)]
# Gen. 70 (14.00%): Max/Min/Avg Fitness(Raw) [23.03(25.00)/16.42(15.00)/19.19(19.19)]
# Gen. 80 (16.00%): Max/Min/Avg Fitness(Raw) [22.93(25.00)/15.79(14.00)/19.11(19.11)]
# Gen. 90 (18.00%): Max/Min/Avg Fitness(Raw) [22.66(25.00)/16.49(15.00)/18.88(18.89)]
# Gen. 100 (20.00%): Max/Min/Avg Fitness(Raw) [22.91(26.00)/16.28(14.00)/19.09(19.09)]
# Gen. 110 (22.00%): Max/Min/Avg Fitness(Raw) [23.31(26.00)/16.81(15.00)/19.43(19.43)]
# Gen. 120 (24.00%): Max/Min/Avg Fitness(Raw) [22.64(26.00)/16.29(14.00)/18.87(18.87)]
# Gen. 130 (26.00%): Max/Min/Avg Fitness(Raw) [23.36(26.00)/17.40(16.00)/19.46(19.46)]
# Gen. 140 (28.00%): Max/Min/Avg Fitness(Raw) [23.26(26.00)/16.23(14.00)/19.38(19.39)]
# Gen. 150 (30.00%): Max/Min/Avg Fitness(Raw) [22.63(26.00)/16.29(14.00)/18.86(18.86)]
# Gen. 160 (32.00%): Max/Min/Avg Fitness(Raw) [22.90(26.00)/16.83(15.00)/19.08(19.08)]
# Gen. 170 (34.00%): Max/Min/Avg Fitness(Raw) [23.17(26.00)/16.82(15.00)/19.31(19.31)]
# Gen. 180 (36.00%): Max/Min/Avg Fitness(Raw) [23.17(26.00)/16.24(14.00)/19.31(19.31)]
# Gen. 190 (38.00%): Max/Min/Avg Fitness(Raw) [22.45(26.00)/16.29(14.00)/18.71(18.71)]
# Gen. 200 (40.00%): Max/Min/Avg Fitness(Raw) [22.03(26.00)/16.26(14.00)/18.36(18.36)]
# Gen. 210 (42.00%): Max/Min/Avg Fitness(Raw) [22.95(26.00)/16.83(15.00)/19.13(19.12)]
# Gen. 220 (44.00%): Max/Min/Avg Fitness(Raw) [23.71(26.00)/16.75(15.00)/19.75(19.75)]
# Gen. 230 (46.00%): Max/Min/Avg Fitness(Raw) [23.18(26.00)/16.82(15.00)/19.32(19.32)]
# Gen. 240 (48.00%): Max/Min/Avg Fitness(Raw) [22.93(26.00)/16.83(15.00)/19.10(19.11)]
# Gen. 250 (50.00%): Max/Min/Avg Fitness(Raw) [22.32(26.00)/16.29(14.00)/18.60(18.60)]
# Gen. 260 (52.00%): Max/Min/Avg Fitness(Raw) [22.45(26.00)/16.81(15.00)/18.71(18.71)]
# Gen. 270 (54.00%): Max/Min/Avg Fitness(Raw) [22.36(26.00)/15.78(13.00)/18.63(18.64)]
# Gen. 280 (56.00%): Max/Min/Avg Fitness(Raw) [22.97(26.00)/16.83(15.00)/19.14(19.14)]
# Gen. 290 (58.00%): Max/Min/Avg Fitness(Raw) [22.87(26.00)/16.83(15.00)/19.06(19.06)]
# Gen. 300 (60.00%): Max/Min/Avg Fitness(Raw) [23.24(26.00)/16.82(15.00)/19.36(19.36)]
# Gen. 310 (62.00%): Max/Min/Avg Fitness(Raw) [23.21(26.00)/16.82(15.00)/19.34(19.34)]
# Gen. 320 (64.00%): Max/Min/Avg Fitness(Raw) [23.50(26.00)/16.17(14.00)/19.58(19.59)]
# Gen. 330 (66.00%): Max/Min/Avg Fitness(Raw) [22.51(26.00)/16.29(14.00)/18.76(18.76)]
# Gen. 340 (68.00%): Max/Min/Avg Fitness(Raw) [22.31(26.00)/16.29(14.00)/18.59(18.59)]
# Gen. 350 (70.00%): Max/Min/Avg Fitness(Raw) [23.02(26.00)/16.27(14.00)/19.18(19.18)]
# Gen. 360 (72.00%): Max/Min/Avg Fitness(Raw) [23.14(26.00)/16.82(15.00)/19.28(19.29)]
# Gen. 370 (74.00%): Max/Min/Avg Fitness(Raw) [23.68(27.00)/17.16(15.00)/19.73(19.73)]
# Gen. 380 (76.00%): Max/Min/Avg Fitness(Raw) [23.54(27.00)/17.16(15.00)/19.61(19.61)]
# Gen. 390 (78.00%): Max/Min/Avg Fitness(Raw) [23.69(27.00)/17.16(15.00)/19.74(19.74)]
# Gen. 400 (80.00%): Max/Min/Avg Fitness(Raw) [23.29(27.00)/16.64(14.00)/19.40(19.41)]
# Gen. 410 (82.00%): Max/Min/Avg Fitness(Raw) [24.78(27.00)/17.63(16.00)/20.65(20.65)]
# Gen. 420 (84.00%): Max/Min/Avg Fitness(Raw) [23.56(27.00)/17.70(16.00)/19.63(19.63)]
# Gen. 430 (86.00%): Max/Min/Avg Fitness(Raw) [23.50(27.00)/17.69(16.00)/19.58(19.59)]
# Gen. 440 (88.00%): Max/Min/Avg Fitness(Raw) [23.00(27.00)/16.64(14.00)/19.17(19.16)]
# Gen. 450 (90.00%): Max/Min/Avg Fitness(Raw) [23.42(27.00)/16.64(14.00)/19.52(19.52)]
# Gen. 460 (92.00%): Max/Min/Avg Fitness(Raw) [23.59(27.00)/16.63(14.00)/19.66(19.66)]
# Gen. 470 (94.00%): Max/Min/Avg Fitness(Raw) [23.33(27.00)/17.16(15.00)/19.44(19.44)]
# Gen. 480 (96.00%): Max/Min/Avg Fitness(Raw) [24.05(27.00)/17.14(15.00)/20.05(20.05)]
# Gen. 490 (98.00%): Max/Min/Avg Fitness(Raw) [23.72(27.00)/17.16(15.00)/19.77(19.77)]
# Gen. 500 (100.00%): Max/Min/Avg Fitness(Raw) [23.84(27.00)/17.71(16.00)/19.87(19.87)]
# Total time elapsed: 8.310 seconds.
# M
# E
# T
# H
# I
# N
# K
# _
# _
# I
# T
# _
# I
# S
# _
# L
# I
# K
# E
# _
# A
# _
# W
# E
# A
# S
# E
# L
